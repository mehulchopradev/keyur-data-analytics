# %%
import numpy as np
import pandas as pd
from pandas import DataFrame
import matplotlib.pyplot as plt

# %%
users = '/home/mehul/Documents/data-analysis-data/data-analysis-data/movielens/users.dat'
col_names = ['user_id', 'gender', 'age', 'occupation', 'zipcode']
users_df = pd.read_csv(users, header=None, names=col_names, sep='::')
users_df
# Out:
# /home/mehul/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:3: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   This is separate from the ipykernel package so we can avoid doing imports until
#       user_id gender  age  occupation zipcode
# 0           1      F    1          10   48067
# 1           2      M   56          16   70072
# 2           3      M   25          15   55117
# 3           4      M   45           7   02460
# 4           5      M   25          20   55455
# 5           6      F   50           9   55117
# 6           7      M   35           1   06810
# 7           8      M   25          12   11413
# 8           9      M   25          17   61614
# 9          10      F   35           1   95370
# 10         11      F   25           1   04093
# ...

# %%
movies = '/home/mehul/Documents/data-analysis-data/data-analysis-data/movielens/movies.dat'
col_names = ['movie_id', 'title', 'genres']
movies_df = pd.read_csv(movies, header=None, names=col_names, sep='::')
movies_df
# Out:
# /home/mehul/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:3: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   This is separate from the ipykernel package so we can avoid doing imports until
#       movie_id                                              title  \
# 0            1                                   Toy Story (1995)
# 1            2                                     Jumanji (1995)
# 2            3                            Grumpier Old Men (1995)
# 3            4                           Waiting to Exhale (1995)
# 4            5                 Father of the Bride Part II (1995)
# 5            6                                        Heat (1995)
# 6            7                                     Sabrina (1995)
# ...

# %%
ratings = '/home/mehul/Documents/data-analysis-data/data-analysis-data/movielens/ratings.dat'
col_names = ['user_id', 'movie_id', 'ratings', 'timestamp']
ratings_df = pd.read_csv(ratings, header=None, names=col_names, sep='::')
ratings_df
# Out:
# /home/mehul/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:3: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   This is separate from the ipykernel package so we can avoid doing imports until
#          user_id  movie_id  ratings  timestamp
# 0              1      1193        5  978300760
# 1              1       661        3  978302109
# 2              1       914        3  978301968
# 3              1      3408        4  978300275
# 4              1      2355        5  978824291
# 5              1      1197        3  978302268
# 6              1      1287        5  978302039
# 7              1      2804        5  978300719
# 8              1       594        4  978302268
# 9              1       919        4  978301368
# 10             1       595        5  978824268
# ...

# %%
d1 = (ratings_df.merge(movies_df)).merge(users_df)
d1
# Out:
#          user_id  movie_id  ratings  timestamp  \
# 0              1      1193        5  978300760
# 1              1       661        3  978302109
# 2              1       914        3  978301968
# 3              1      3408        4  978300275
# 4              1      2355        5  978824291
# 5              1      1197        3  978302268
# 6              1      1287        5  978302039
# 7              1      2804        5  978300719
# 8              1       594        4  978302268
# 9              1       919        4  978301368
# 10             1       595        5  978824268
# 11             1       938        4  978301752
# 12             1      2398        4  978302281
# 13             1      2918        4  978302124
# 14             1      1035        5  978301753
# 15             1      2791        4  978302188
# 16             1      2687        3  978824268
# 17             1      2018        4  978301777
# 18             1      3105        5  978301713
# ...

# %% [markdown]
# # popular films. A film where there is minimum sample size (number of people who voted) of 500

# %%
s1 = d1['title']
s1
# Out:
# 0                     One Flew Over the Cuckoo's Nest (1975)
# 1                           James and the Giant Peach (1996)
# 2                                        My Fair Lady (1964)
# 3                                     Erin Brockovich (2000)
# 4                                       Bug's Life, A (1998)
# 5                                 Princess Bride, The (1987)
# 6                                             Ben-Hur (1959)
# 7                                  Christmas Story, A (1983)
# 8                     Snow White and the Seven Dwarfs (1937)
# 9                                   Wizard of Oz, The (1939)
# 10                               Beauty and the Beast (1991)
# 11                                               Gigi (1958)
# 12                             Miracle on 34th Street (1947)
# 13                           Ferris Bueller's Day Off (1986)
# 14                                Sound of Music, The (1965)
# ...

# %%
s2 = s1.value_counts()
s3 = s2[s2 >= 500]
popular_films = s3.index
popular_films
# Out:
# Index(['American Beauty (1999)', 'Star Wars: Episode IV - A New Hope (1977)',
#        'Star Wars: Episode V - The Empire Strikes Back (1980)',
#        'Star Wars: Episode VI - Return of the Jedi (1983)',
#        'Jurassic Park (1993)', 'Saving Private Ryan (1998)',
#        'Terminator 2: Judgment Day (1991)', 'Matrix, The (1999)',
#        'Back to the Future (1985)', 'Silence of the Lambs, The (1991)',
#        ...
#        'Ordinary People (1980)', 'Peggy Sue Got Married (1986)',
#        'Halloween (1978)', '28 Days (2000)', 'Alien Nation (1988)',
#        'Body Heat (1981)', 'Guns of Navarone, The (1961)', 'Emma (1996)',
#        'Postino, Il (The Postman) (1994)', 'Last Action Hero (1993)'],
#       dtype='object', length=618)

# %%
d2 = d1[['title', 'gender', 'ratings']]
d2
# Out:
#                                                      title gender  ratings
# 0                   One Flew Over the Cuckoo's Nest (1975)      F        5
# 1                         James and the Giant Peach (1996)      F        3
# 2                                      My Fair Lady (1964)      F        3
# 3                                   Erin Brockovich (2000)      F        4
# 4                                     Bug's Life, A (1998)      F        5
# 5                               Princess Bride, The (1987)      F        3
# 6                                           Ben-Hur (1959)      F        5
# 7                                Christmas Story, A (1983)      F        5
# 8                   Snow White and the Seven Dwarfs (1937)      F        4
# 9                                 Wizard of Oz, The (1939)      F        4
# 10                             Beauty and the Beast (1991)      F        5
# ...

# %%
d3 = d2.pivot_table('ratings', aggfunc='mean', index='title', columns=['gender'])
d4 = d3.loc[popular_films]
d5 = d4.sort_values(by='M', ascending=False)
d6 = d5.head(15)
d6
# Out:
# gender                                                     F         M
# Godfather, The (1972)                               4.314700  4.583333
# Seven Samurai (The Magnificent Seven) (Shichini...  4.481132  4.576628
# Shawshank Redemption, The (1994)                    4.539075  4.560625
# Raiders of the Lost Ark (1981)                      4.332168  4.520597
# Usual Suspects, The (1995)                          4.513317  4.518248
# Star Wars: Episode IV - A New Hope (1977)           4.302937  4.495307
# Schindler's List (1993)                             4.562602  4.491415
# Wrong Trousers, The (1993)                          4.588235  4.478261
# Close Shave, A (1995)                               4.644444  4.473795
# Rear Window (1954)                                  4.484536  4.472991
# Double Indemnity (1944)                             4.282051  4.468354
# Dr. Strangelove or: How I Learned to Stop Worry...  4.376623  4.464789
# ...

# %%
d6.plot(kind='barh')
plt.show()
