# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
file_path = '/home/mehul/Documents/training/python/data/daily-min-temperatures.csv'

# %%
df = pd.read_csv(file_path, parse_dates=['Date'], index_col=0)
df
# Out:
#             Temp
# Date
# 1981-01-01  20.7
# 1981-01-02  17.9
# 1981-01-03  18.8
# 1981-01-04  14.6
# 1981-01-05  15.8
# ...          ...
# 1990-12-27  14.0
# 1990-12-28  13.6
# 1990-12-29  13.5
# 1990-12-30  15.7
# 1990-12-31  13.0
#
# [3650 rows x 1 columns]

# %%
from statsmodels.graphics.tsaplots import plot_acf

# %%
plot_acf(df)
plt.show()

# %%
# q = 1

# %%
x = df.values.ravel()
x
# Out:
# array([20.7, 17.9, 18.8, ..., 13.5, 15.7, 13. ])

# %%
partition = round(0.70 * len(x))
train, test = x[:partition], x[partition:]

# %%
history = [x for x in train]
predictions = []

# %%
from statsmodels.tsa.arima_model import ARMA

# %%
for i in range(len(test)):
    model = ARMA(history, order=(1, 1)) # p = 0 (MA Model)
    model_fit = model.fit()
    prediction_list = model_fit.forecast()
    predictions.append(prediction_list[0][0])
    history.append(test[i])
    print('Predicted {0}'.format(prediction_list[0][0]))
    print('Expected {0}'.format(test[i]))
# Out:
# Predicted 15.043574674638865
# Expected 15.3
# Predicted 14.62346465115407
# Expected 14.3
# Predicted 13.900578474219333
# Expected 13.5
# Predicted 13.233149344671133
# Expected 15.0
# Predicted 14.01957540033424
# Expected 13.6
# Predicted 13.324832880870433
# Expected 15.2
# Predicted 14.166146311257545
# Expected 17.0
# Predicted 15.488155147598142
# Expected 18.7
# Predicted 16.861719805249564
# Expected 16.5
# Predicted 15.79952788627794
# Expected 17.4
# Predicted 16.12119672357452
# Expected 18.3
# Predicted 16.761480149811312
# Expected 18.3
# Predicted 16.91217311025155
# Expected 22.4
# Predicted 19.521671300902476
# Expected 21.4
# Predicted 19.509597263071658
# Expected 20.9
# Predicted 19.197347788701997
# Expected 17.6
# Predicted 17.049091007095495
# Expected 15.5
# Predicted 15.225385690238104
# Expected 16.6
# Predicted 15.500909641248748
# Expected 16.2
# Predicted 15.313656936778123
# Expected 15.6
# Predicted 14.894370688458377
# Expected 14.5
# Predicted 14.106900711093695
# Expected 14.0
# Predicted 13.61042975918978
# Expected 15.6
# Predicted 14.498824336152929
# Expected 12.3
# Predicted 12.63841236221019
# Expected 11.6
# Predicted 11.764421416518335
# Expected 12.6
# Predicted 12.188288782963726
# Expected 14.9
# Predicted 13.728042211527356
# Expected 17.3
# Predicted 15.595283357853697
# Expected 21.4
# Predicted 18.61741268375167
# Expected 23.4
# Predicted 20.585869651424893
# Expected 14.4
# Predicted 15.327932732365689
# Expected 14.1
# Predicted 13.93929048698976
# Expected 15.0
# Predicted 14.2016580672062
# Expected 14.5
# Predicted 13.944570251261968
# Expected 15.1
# Predicted 14.266036258640884
# Expected 13.9
# Predicted 13.58109162649418
# Expected 13.4
# Predicted 13.110344241725276
# Expected 9.2
# Predicted 10.34725251012456
# Expected 12.5
# Predicted 11.810103932340763
# Expected 15.1
# Predicted 13.782433383996523
# Expected 12.1
# Predicted 12.336567083990989
# Expected 14.5
# Predicted 13.521170935034405
# Expected 16.3
# Predicted 14.926954589480031
# Expected 16.5
# Predicted 15.374361990086479
# Expected 14.9
# Predicted 14.466265217256117
# Expected 13.2
# Predicted 13.185884899416555
# Expected 11.8
# Predicted 12.010414977016493
# Expected 13.6
# Predicted 12.88256972627431
# Expected 16.2
# Predicted 14.722090463249945
# Expected 14.1
# Predicted 13.813005570129546
# Expected 13.5
# Predicted 13.228282860174918
# Expected 15.0
# Predicted 14.043081602660116
# Expected 14.8
# Predicted 14.102320240870064
# Expected 16.2
# Predicted 15.00008029801574
# Expected 16.2
# Predicted 15.20515873289936
# Expected 13.3
# Predicted 13.420475205451952
# Expected 15.3
# Predicted 14.278144331070855
# Expected 18.4
# Predicted 16.429470713368833
# Expected 16.2
# Predicted 15.534915872269046
# Expected 16.3
# Predicted 15.394479254965002
# Expected 12.4
# Predicted 12.899807750374642
# Expected 15.6
# Predicted 14.348835129561705
# Expected 14.9
# Predicted 14.241338276251543
# Expected 14.8
# Predicted 14.154049711407595
# Expected 12.7
# Predicted 12.81243988183508
# Expected 14.2
# Predicted 13.446921459058315
# Expected 16.8
# Predicted 15.228566309605077
# Expected 16.7
# Predicted 15.579656468067967
# Expected 16.2
# Predicted 15.346562634553415
# Expected 14.5
# Predicted 14.222305101848717
# Expected 10.0
# Predicted 11.120129772849605
# Expected 12.6
# Predicted 12.053527286495171
# Expected 11.9
# Predicted 11.825877245066259
# Expected 11.8
# Predicted 11.710599489486771
# Expected 13.4
# Predicted 12.69120659920921
# Expected 14.5
# Predicted 13.61003836776048
# Expected 15.7
# Predicted 14.578008061792188
# Expected 15.3
# Predicted 14.548094192976006
# Expected 13.9
# Predicted 13.658455758309785
# Expected 13.7
# Predicted 13.328899791579737
# Expected 15.1
# Predicted 14.136421325395517
# Expected 15.6
# Predicted 14.637440119742628
# Expected 14.4
# Predicted 13.996185004059486
# Expected 13.9
# Predicted 13.534012776860422
# Expected 16.2
# Predicted 14.877865132118197
# Expected 16.7
# Predicted 15.503467263307797
# Expected 15.5
# Predicted 14.891283087942753
# Expected 16.4
# Predicted 15.318959169795415
# Expected 17.5
# Predicted 16.112078452121658
# Expected 18.2
# Predicted 16.73834247319441
# Expected 16.1
# Predicted 15.559087815306142
# Expected 16.5
# Predicted 15.54061168412881
# Expected 14.6
# Predicted 14.338328100075993
# Expected 16.4
# Predicted 15.195754421377652
# Expected 13.6
# Predicted 13.632265840360338
# Expected 15.9
# Predicted 14.716279997366245
# Expected 11.9
# Predicted 12.45676155209822
# Expected 14.7
# Predicted 13.685291409456969
# Expected 9.4
# Predicted 10.655107453349748
# Expected 6.6
# Predicted 8.17158502458616
# Expected 7.9
# Predicted 8.414794090818804
# Expected 11.0
# Predicted 10.421382375459022
# Expected 15.7
# Predicted 13.859064214986804
# Expected 15.2
# Predicted 14.328598841456873
# Expected 15.9
# Predicted 14.877165660645545
# Expected 10.6
# Predicted 11.647984590878007
# Expected 8.3
# Predicted 9.450130072755982
# Expected 8.6
# Predicted 9.152865229565903
# Expected 12.7
# Predicted 11.689650556325208
# Expected 10.5
# Predicted 10.859296887839047
# Expected 12.0
# Predicted 11.624841940394758
# Expected 11.1
# Predicted 11.22587504062079
# Expected 13.0
# Predicted 12.340600285293498
# Expected 12.4
# Predicted 12.21045514168894
# Expected 13.3
# Predicted 12.751758706342642
# Expected 15.9
# Predicted 14.522157347008504
# Expected 12.0
# Predicted 12.448327691701998
# Expected 13.7
# Predicted 13.058688182669512
# Expected 17.6
# Predicted 15.664458580500519
# Expected 14.3
# Predicted 14.166893458970655
# Expected 13.7
# Predicted 13.448146857227728
# Expected 15.2
# Predicted 14.233987446216155
# Expected 14.5
# Predicted 13.97057899860848
# Expected 14.9
# Predicted 14.163837752649075
# Expected 15.5
# Predicted 14.587432662484957
# Expected 16.4
# Predicted 15.253415405429331
# Expected 14.5
# Predicted 14.204971198843776
# Expected 12.6
# Predicted 12.763942418264275
# Expected 13.6
# Predicted 13.069341535578916
# Expected 11.2
# Predicted 11.62222572635608
# Expected 11.0
# Predicted 11.166329934242917
# Expected 12.0
# Predicted 11.694745820328421
# Expected 6.8
# Predicted 8.531369498936412
# Expected 10.6
# Predicted 10.207183216532629
# Expected 13.1
# Predicted 12.168556546080161
# Expected 13.5
# Predicted 12.870112326712832
# Expected 11.7
# Predicted 11.893234887994213
# Expected 13.2
# Predicted 12.61717021168366
# Expected 12.0
# Predicted 12.02551976395624
# Expected 10.4
# Predicted 10.88055801023141
# Expected 10.0
# Predicted 10.36664455594048
# Expected 8.2
# Predicted 9.112556589903889
# Expected 9.4
# Predicted 9.585414240499222
# Expected 10.3
# Predicted 10.261355075435866
# Expected 8.1
# Predicted 9.02583212415208
# Expected 8.7
# Predicted 9.122927461325668
# Expected 12.6
# Predicted 11.607592205652237
# Expected 10.9
# Predicted 11.09982071453119
# Expected 8.7
# Predicted 9.596470637232327
# Expected 9.3
# Predicted 9.631709795894766
# Expected 6.3
# Predicted 7.746142980563437
# Expected 7.8
# Predicted 8.262567821899925
# Expected 10.0
# Predicted 9.769589322065958
# Expected 11.0
# Predicted 10.745130167032265
# Expected 11.1
# Predicted 11.029445905389663
# Expected 12.6
# Predicted 12.041926603708495
# Expected 10.2
# Predicted 10.755293934348746
# Expected 11.1
# Predicted 11.03158812817386
# Expected 8.7
# Predicted 9.57891584808675
# Expected 9.5
# Predicted 9.753758470062726
# Expected 9.7
# Predicted 9.919703115793817
# Expected 8.2
# Predicted 9.01013765631611
# Expected 5.0
# Predicted 6.779947569750218
# Expected 6.5
# Predicted 7.222132353077714
# Expected 12.1
# Predicted 10.867167923224958
# Expected 8.9
# Predicted 9.665529507906026
# Expected 6.1
# Predicted 7.6270306270762465
# Expected 2.8
# Predicted 5.0699524527627755
# Expected 3.7
# Predicted 5.062976879136776
# Expected 6.8
# Predicted 7.0291632952362075
# Expected 6.6
# Predicted 7.341721418651967
# Expected 7.0
# Predicted 7.665057587507715
# Expected 7.3
# Predicted 7.927363564186793
# Expected 7.9
# Predicted 8.366266790571187
# Expected 10.6
# Predicted 10.177279518638205
# Expected 8.1
# Predicted 8.999069271751399
# Expected 6.7
# Predicted 7.847139091689948
# Expected 8.0
# Predicted 8.410437409472207
# Expected 10.0
# Predicted 9.80448432744184
# Expected 6.7
# Predicted 8.029854674488487
# Expected 9.4
# Predicted 9.334342298574443
# Expected 9.3
# Predicted 9.567292736585719
# Expected 6.0
# Predicted 7.53618130940964
# Expected 5.8
# /home/mehul/anaconda3/lib/python3.7/site-packages/statsmodels/base/model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# Predicted 6.945263344821432
# Expected 4.9
# Predicted 6.240839035783796
# Expected 5.0
# Predicted 6.142957972941304
# Expected 8.4
# Predicted 8.273500214957142
# Expected 12.3
# Predicted 11.237834422021697
# Expected 13.0
# Predicted 12.345075259358113
# Expected 11.4
# Predicted 11.570934400683118
# Expected 6.8
# Predicted 8.47374392244514
# Expected 7.6
# Predicted 8.297377045888915
# Expected 12.4
# Predicted 11.31262309593911
# Expected 7.1
# Predicted 8.615640715944753
# Expected 7.5
# Predicted 8.26546395385941
# Expected 10.0
# Predicted 9.771413244902257
# Expected 5.3
# Predicted 7.13555091145429
# Expected 6.3
# Predicted 7.170771785609157
# Expected 8.0
# Predicted 8.254420727023719
# Expected 8.3
# Predicted 8.688922575429709
# Expected 9.3
# Predicted 9.419849863692866
# Expected 9.5
# Predicted 9.7112749852619
# Expected 5.6
# Predicted 7.31139926112437
# Expected 7.0
# Predicted 7.651737182822533
# Expected 8.5
# Predicted 8.677478910129754
# Expected 8.5
# Predicted 8.90949995426212
# Expected 8.2
# Predicted 8.772135313967372
# Expected 8.5
# Predicted 8.930430279908062
# Expected 9.6
# Predicted 9.66165428902413
# Expected 9.7
# Predicted 9.890556321372067
# Expected 7.1
# Predicted 8.299483323684361
# Expected 8.4
# Predicted 8.758971808892866
# Expected 9.2
# Predicted 9.368809493446891
# Expected 9.8
# Predicted 9.886512400830814
# Expected 8.1
# Predicted 8.930048269816261
# Expected 9.4
# Predicted 9.533222776749984
# Expected 10.0
# Predicted 10.049481140052363
# Expected 5.1
# Predicted 7.075638020396366
# Expected 6.7
# Predicted 7.403728931810578
# Expected 6.9
# Predicted 7.604667927903933
# Expected 6.8
# Predicted 7.586877195253233
# Expected 8.6
# Predicted 8.718954814866178
# Expected 9.1
# Predicted 9.293473078580442
# Expected 3.9
# Predicted 6.147366780280365
# Expected 4.8
# Predicted 5.987768274556415
# Expected 8.4
# Predicted 8.223244656969728
# Expected 11.6
# Predicted 10.76504386027371
# Expected 12.1
# Predicted 11.657523230947334
# Expected 12.4
# Predicted 12.04762550044247
# Expected 10.0
# Predicted 10.615931127541819
# Expected 10.1
# Predicted 10.356533231959439
# Expected 9.7
# Predicted 10.04484500579217
# Expected 11.7
# Predicted 11.240916535944574
# Expected 7.9
# Predicted 9.106912228190263
# Expected 8.6
# Predicted 9.066500923680621
# Expected 7.7
# Predicted 8.487876733297892
# Expected 5.8
# Predicted 7.153874768258749
# Expected 8.7
# Predicted 8.687425941923333
# Expected 10.6
# Predicted 10.238486223336126
# Expected 6.7
# Predicted 8.121618310130476
# Expected 8.8
# Predicted 8.967066484946313
# Expected 9.7
# Predicted 9.727997997580793
# Expected 9.0
# Predicted 9.45897117331619
# Expected 11.8
# Predicted 11.165474449163023
# Expected 15.2
# Predicted 13.707748525025051
# Expected 10.0
# Predicted 10.997547677780823
# Expected 10.5
# Predicted 10.695439569727451
# Expected 5.5
# Predicted 7.46820014562368
# Expected 9.4
# Predicted 9.19650899362645
# Expected 8.8
# Predicted 9.211822524998027
# Expected 5.3
# Predicted 7.010052356209189
# Expected 13.0
# Predicted 11.339271618759595
# Expected 15.2
# Predicted 13.742585038092532
# Expected 13.2
# Predicted 13.023098975999503
# Expected 11.5
# Predicted 11.787600181263826
# Expected 6.8
# Predicted 8.534506274728438
# Expected 4.7
# Predicted 6.462346094218176
# Expected 5.2
# Predicted 6.322601149598229
# Expected 6.8
# Predicted 7.309015096923387
# Expected 10.7
# Predicted 10.01133529665053
# Expected 10.1
# Predicted 10.221173647559612
# Expected 10.0
# Predicted 10.203381460985128
# Expected 9.8
# Predicted 10.072201586117306
# Expected 5.5
# Predicted 7.307748821439203
# Expected 13.5
# Predicted 11.76912233506321
# Expected 16.6
# Predicted 14.749634193457338
# Expected 8.4
# Predicted 10.202138506005344
# Expected 8.2
# Predicted 9.056924018621089
# Expected 11.1
# Predicted 10.640300094149023
# Expected 10.8
# Predicted 10.803253540090155
# Expected 8.8
# Predicted 9.574514508670562
# Expected 10.8
# Predicted 10.564623253071186
# Expected 8.7
# Predicted 9.458748533890397
# Expected 12.4
# Predicted 11.547176812146242
# Expected 9.0
# Predicted 9.872246524044916
# Expected 13.5
# Predicted 12.326669362137148
# Expected 14.7
# Predicted 13.64336707709073
# Expected 10.9
# Predicted 11.547371631551824
# Expected 8.5
# Predicted 9.555821839121155
# Expected 6.0
# Predicted 7.523969706148182
# Expected 12.7
# Predicted 11.29576115311304
# Expected 11.1
# Predicted 11.139451538857719
# Expected 8.7
# Predicted 9.593717541527514
# Expected 12.3
# Predicted 11.50629265884076
# Expected 13.3
# Predicted 12.57217096248565
# Expected 5.6
# Predicted 7.9836153596688675
# Expected 13.7
# Predicted 11.981634375057116
# Expected 8.5
# Predicted 9.693664184033459
# Expected 11.2
# Predicted 10.818211678022074
# Expected 8.7
# Predicted 9.5422178308545
# Expected 11.7
# Predicted 11.088600505262384
# Expected 12.5
# Predicted 11.958725040419857
# Expected 8.2
# Predicted 9.512536065938711
# Expected 15.6
# Predicted 13.471686892016915
# Expected 10.3
# Predicted 11.19624210883823
# Expected 11.4
# Predicted 11.303282468257551
# Expected 9.7
# Predicted 10.289042438504536
# Expected 6.3
# Predicted 7.949020942405478
# Expected 14.3
# Predicted 12.250751326811377
# Expected 11.3
# Predicted 11.50911223885573
# Expected 7.3
# Predicted 8.886151631395757
# Expected 12.8
# Predicted 11.557488784077586
# Expected 11.9
# Predicted 11.698837923310087
# Expected 14.3
# Predicted 13.192329500195859
# Expected 11.6
# Predicted 11.938439966014979
# Expected 13.2
# Predicted 12.585647107694523
# Expected 15.5
# Predicted 14.148086111175381
# Expected 14.1
# Predicted 13.702869563154417
# Expected 9.5
# Predicted 10.795537606433195
# Expected 7.2
# Predicted 8.638974329631237
# Expected 11.8
# Predicted 10.891347283711008
# Expected 16.8
# Predicted 14.517844991370133
# Expected 12.5
# Predicted 12.81826971419854
# Expected 9.4
# Predicted 10.49919592555429
# Expected 11.9
# Predicted 11.429119608244681
# Expected 10.3
# Predicted 10.694395311160116
# Expected 16.9
# Predicted 14.508836994137642
# Expected 17.5
# Predicted 15.862545122854971
# Expected 7.5
# Predicted 10.145549113369428
# Expected 8.6
# Predicted 9.330157410866125
# Expected 11.1
# Predicted 10.642494294645191
# Expected 11.5
# Predicted 11.22143602077357
# Expected 10.7
# Predicted 10.884931164604536
# Expected 15.7
# Predicted 13.828600486801376
# Expected 12.8
# Predicted 12.828138920000779
# Expected 13.0
# Predicted 12.692239943495496
# Expected 12.9
# Predicted 12.596787249320386
# Expected 14.3
# Predicted 13.419741917142808
# Expected 13.7
# Predicted 13.269199172407772
# Expected 12.1
# Predicted 12.261763766253319
# Expected 11.9
# Predicted 11.880767017996034
# Expected 11.8
# Predicted 11.722106225453444
# Expected 11.4
# Predicted 11.439069497313731
# Expected 10.3
# Predicted 10.700031633374046
# Expected 11.7
# Predicted 11.357244581832202
# Expected 12.0
# Predicted 11.708284276870245
# Expected 17.4
# Predicted 15.071048489325207
# Expected 16.8
# Predicted 15.574416709293791
# Expected 16.2
# Predicted 15.337219244935387
# Expected 13.0
# Predicted 13.330497076879096
# Expected 12.5
# Predicted 12.514844991151953
# Expected 12.4
# Predicted 12.247600115252002
# Expected 16.1
# Predicted 14.4280151767306
# Expected 20.2
# Predicted 17.488136066393462
# Expected 14.3
# Predicted 14.666591767004602
# Expected 11.0
# Predicted 11.930897985477442
# Expected 14.4
# Predicted 13.318623985299238
# Expected 15.7
# Predicted 14.458775976588154
# Expected 19.7
# Predicted 17.186886067089695
# Expected 20.7
# Predicted 18.49344772014992
# Expected 23.9
# Predicted 20.789563074855774
# Expected 16.6
# Predicted 16.885120657025563
# Expected 17.5
# Predicted 16.46442799568298
# Expected 14.9
# Predicted 14.764802215397514
# Expected 13.6
# Predicted 13.542972729190506
# Expected 11.9
# Predicted 12.196394946667139
# Expected 15.2
# Predicted 13.882984643600016
# Expected 17.3
# Predicted 15.589820632547388
# Expected 19.8
# Predicted 17.55213794368416
# Expected 15.8
# Predicted 15.582701460849925
# Expected 9.5
# Predicted 11.205464005880234
# Expected 12.9
# Predicted 12.237255818495118
# Expected 12.9
# Predicted 12.487182297818332
# Expected 14.8
# Predicted 13.714567627836713
# Expected 14.1
# Predicted 13.587716654107517
# Expected 14.3
# Predicted 13.679470020763308
# Expected 17.4
# Predicted 15.605055894513479
# Expected 18.5
# Predicted 16.75858657081228
# Expected 16.8
# Predicted 15.996608318039748
# Expected 11.5
# Predicted 12.541704144394743
# Expected 9.5
# Predicted 10.456318211547774
# Expected 12.2
# Predicted 11.628974331510697
# Expected 15.7
# Predicted 14.070888666049038
# Expected 16.3
# Predicted 15.031997100837632
# Expected 13.6
# Predicted 13.591779720714923
# Expected 12.6
# Predicted 12.627926785255896
# Expected 13.8
# Predicted 13.139964166664553
# Expected 12.1
# Predicted 12.21196372108532
# Expected 13.4
# Predicted 12.792908404318037
# Expected 17.3
# Predicted 15.342432643365237
# Expected 19.4
# Predicted 17.26063037154452
# Expected 16.6
# Predicted 15.978366890879649
# Expected 13.9
# Predicted 13.996147711268028
# Expected 13.1
# Predicted 13.02995619923896
# Expected 16.0
# Predicted 14.60217422433446
# Expected 14.5
# Predicted 14.045540013932161
# Expected 15.0
# Predicted 14.223648967693272
# Expected 12.6
# Predicted 12.778597721771142
# Expected 12.5
# Predicted 12.37319876012447
# Expected 15.2
# Predicted 13.94919962852255
# Expected 16.2
# Predicted 14.94532844027768
# Expected 16.5
# Predicted 15.368828279600715
# Expected 20.1
# Predicted 17.705791523692604
# Expected 20.6
# Predicted 18.57577088215254
# Expected 16.9
# Predicted 16.4779633623493
# Expected 16.5
# Predicted 15.73493641305502
# Expected 16.1
# Predicted 15.31179733701906
# Expected 14.4
# Predicted 14.154208189214405
# Expected 16.3
# Predicted 15.063202516628186
# Expected 15.7
# Predicted 14.906269375690702
# Expected 14.2
# Predicted 13.93752849078475
# Expected 13.2
# Predicted 13.086354523358922
# Expected 16.8
# Predicted 15.118894097376318
# Expected 18.5
# Predicted 16.66134157464629
# Expected 16.7
# Predicted 15.909418776234556
# Expected 15.3
# Predicted 14.86076832566879
# Expected 15.9
# Predicted 14.986218321031133
# Expected 15.2
# Predicted 14.581466791482537
# Expected 17.5
# Predicted 15.914116025690088
# Expected 18.3
# Predicted 16.73067847284774
# Expected 19.4
# Predicted 17.611466159862882
# Expected 19.4
# Predicted 17.823950883529893
# Expected 19.5
# Predicted 17.93965528137081
# Expected 20.5
# Predicted 18.593331833267378
# Expected 15.7
# Predicted 15.762138753872065
# Expected 15.0
# Predicted 14.648461685211986
# Expected 16.1
# Predicted 15.069701053088849
# Expected 14.3
# Predicted 14.051599265260755
# Expected 13.0
# Predicted 12.999654073391932
# Expected 16.2
# Predicted 14.735680181230574
# Expected 17.7
# Predicted 16.08538841866776
# Expected 13.2
# Predicted 13.616079556104516
# Expected 15.8
# Predicted 14.63602792204689
# Expected 18.5
# Predicted 16.555336928254384
# Expected 20.4
# Predicted 18.203726361013775
# Expected 22.0
# Predicted 19.60116905803049
# Expected 19.7
# Predicted 18.505065685239117
# Expected 19.6
# Predicted 18.1836730239065
# Expected 20.3
# Predicted 18.54621806180516
# Expected 18.3
# Predicted 17.390087712135745
# Expected 18.9
# Predicted 17.487461219635634
# Expected 20.3
# Predicted 18.383797117690644
# Expected 21.4
# Predicted 19.289628069632133
# Expected 18.3
# Predicted 17.585613949795597
# Expected 17.8
# Predicted 16.860605687119037
# Expected 17.7
# Predicted 16.623270406941867
# Expected 12.8
# Predicted 13.517627984782182
# Expected 15.1
# Predicted 14.192915562501542
# Expected 15.0
# Predicted 14.294818299853139
# Expected 14.8
# Predicted 14.196264492741175
# Expected 12.0
# Predicted 12.436855451295909
# Expected 12.5
# Predicted 12.315662530671204
# Expected 15.0
# Predicted 13.833873060156623
# Expected 17.1
# Predicted 15.509829436857434
# Expected 17.3
# Predicted 16.045227730241237
# Expected 16.9
# Predicted 15.927947752601941
# Expected 16.5
# Predicted 15.651731488285206
# Expected 13.6
# Predicted 13.781708219861619
# Expected 13.2
# Predicted 13.077819840782645
# Expected 9.4
# Predicted 10.540503744203
# Expected 9.5
# Predicted 9.990500910377971
# Expected 11.8
# Predicted 11.290982531148373
# Expected 10.4
# Predicted 10.732627451221195
# Expected 9.7
# Predicted 10.162405729619529
# Expected 12.6
# Predicted 11.828901121151166
# Expected 13.3
# Predicted 12.667487629646729
# Expected 15.1
# Predicted 13.991064169715335
# Expected 14.2
# Predicted 13.747837940745875
# Expected 14.2
# Predicted 13.689699140302096
# Expected 19.2
# Predicted 16.791691218491987
# Expected 12.6
# Predicted 13.437389250993647
# Expected 14.2
# Predicted 13.616837896293081
# Expected 11.9
# Predicted 12.232983639687399
# Expected 13.9
# Predicted 13.135956238356888
# Expected 13.5
# Predicted 13.108812618753232
# Expected 15.3
# Predicted 14.21789230736964
# Expected 13.9
# Predicted 13.62217480716004
# Expected 14.0
# Predicted 13.538462866572653
# Expected 12.9
# Predicted 12.83632393481327
# Expected 8.5
# Predicted 9.933185561122578
# Expected 11.4
# Predicted 11.025105092550177
# Expected 10.9
# Predicted 10.981519664100205
# Expected 12.0
# Predicted 11.652231060327237
# Expected 8.6
# Predicted 9.711650059370232
# Expected 9.0
# Predicted 9.482630580501015
# Expected 9.6
# Predicted 9.79813788256347
# Expected 10.2
# Predicted 10.247030048331444
# Expected 9.8
# Predicted 10.109241327561788
# Expected 8.3
# Predicted 9.146512659314038
# Expected 11.0
# Predicted 10.58153108609993
# Expected 11.9
# Predicted 11.49177015586888
# Expected 14.0
# Predicted 13.016979052402965
# Expected 15.8
# Predicted 14.507901705514376
# Expected 14.5
# Predicted 14.062214220574852
# Expected 13.2
# Predicted 13.146608863960202
# Expected 14.2
# Predicted 13.54577863888164
# Expected 14.6
# Predicted 13.891244491789623
# Expected 11.8
# Predicted 12.237123268454233
# Expected 14.4
# Predicted 13.448133213073005
# Expected 10.4
# Predicted 11.265251838137555
# Expected 10.3
# Predicted 10.668344181257785
# Expected 10.8
# Predicted 10.832873587113045
# Expected 10.5
# Predicted 10.68707335727697
# Expected 9.5
# Predicted 10.031587383494898
# Expected 12.5
# Predicted 11.73019102776622
# Expected 13.7
# Predicted 12.890523899155502
# Expected 12.7
# Predicted 12.55276130129872
# Expected 11.9
# Predicted 11.974410293108436
# Expected 11.4
# Predicted 11.523355708534753
# Expected 9.7
# Predicted 10.358676323999678
# Expected 8.3
# Predicted 9.205630887092385
# Expected 8.1
# Predicted 8.80172355787857
# Expected 11.7
# Predicted 10.939883455310236
# Expected 11.6
# Predicted 11.39628998020469
# Expected 7.4
# Predicted 8.900224124987655
# Expected 5.2
# Predicted 6.922384847989385
# Expected 11.0
# Predicted 10.047708749500185
# Expected 9.5
# Predicted 9.875051945194942
# Expected 9.2
# Predicted 9.647290492597842
# Expected 10.7
# Predicted 10.52149825871408
# Expected 9.0
# Predicted 9.681063200002397
# Expected 10.2
# Predicted 10.219235674708246
# Expected 10.3
# Predicted 10.412587680832575
# Expected 12.1
# Predicted 11.575104013106824
# Expected 13.2
# Predicted 12.541169567045044
# Expected 6.6
# Predicted 8.693036831146646
# Expected 2.3
# Predicted 5.057943069908299
# Expected 1.4
# Predicted 3.6230635540731275
# Expected 2.1
# Predicted 3.7263460414229947
# Expected 6.6
# Predicted 6.5783174804627755
# Expected 8.9
# Predicted 8.69693898361995
# Expected 7.8
# Predicted 8.491445696261042
# Expected 9.0
# Predicted 9.198123941311517
# Expected 10.3
# Predicted 10.178953220792852
# Expected 7.9
# Predicted 8.89912663567993
# Expected 7.2
# Predicted 8.161836097242233
# Expected 8.6
# Predicted 8.869436045632746
# Expected 8.8
# Predicted 9.159219284906513
# Expected 6.2
# Predicted 7.594432305982923
# Expected 9.5
# Predicted 9.299414462011612
# Expected 10.2
# Predicted 10.136977299929038
# Expected 9.7
# Predicted 10.018205535559954
# Expected 11.2
# Predicted 10.931301603964974
# Expected 10.2
# Predicted 10.517044286319427
# Expected 10.1
# Predicted 10.357679928957733
# Expected 8.1
# Predicted 9.066256515548409
# Expected 6.6
# Predicted 7.82271728629294
# Expected 5.0
# Predicted 6.526958364601708
# Expected 4.7
# Predicted 6.03688381171299
# Expected 5.3
# Predicted 6.300341466787539
# Expected 4.5
# Predicted 5.856143858737925
# Expected 2.3
# Predicted 4.366064926439499
# Expected 1.4
# Predicted 3.4492886485932077
# Expected 0.5
# Predicted 2.6643936327466426
# Expected 2.4
# Predicted 3.679082631202971
# Expected 8.0
# Predicted 7.461706912611081
# Expected 6.0
# Predicted 7.060136512813788
# Expected 7.1
# Predicted 7.66268211351017
# Expected 9.7
# Predicted 9.44223131861817
# Expected 6.9
# Predicted 8.087863640244835
# Expected 5.3
# Predicted 6.7660460917707645
# Expected 7.0
# Predicted 7.529520912362423
# Expected 6.2
# Predicted 7.202051977415153
# Expected 7.0
# Predicted 7.629249973310775
# Expected 9.7
# Predicted 9.429665943833227
# Expected 8.0
# Predicted 8.776120591156484
# Expected 8.5
# Predicted 8.9388687385939
# Expected 7.1
# Predicted 8.09579510495343
# Expected 7.5
# Predicted 8.150547679976627
# Expected 3.3
# Predicted 5.5202603799636885
# Expected 1.8
# Predicted 3.9553991226807126
# Expected 2.6
# Predicted 4.0966418054455565
# Expected 5.3
# Predicted 5.83561658480527
# Expected 5.8
# Predicted 6.55222424979025
# Expected 5.8
# Predicted 6.716544713808264
# Expected 7.2
# Predicted 7.638393001181571
# Expected 5.3
# Predicted 6.65162933367585
# Expected 1.6
# Predicted 4.085840527740664
# Expected 3.1
# Predicted 4.434329665767882
# Expected 5.3
# Predicted 5.905459743100421
# Expected 7.7
# Predicted 7.766187174195876
# Expected 4.2
# Predicted 5.982452761740947
# Expected 5.5
# Predicted 6.386877204912829
# Expected 9.0
# Predicted 8.690144186618463
# Expected 11.2
# Predicted 10.619414564790242
# Expected 8.0
# Predicted 9.043326478215965
# Expected 7.6
# Predicted 8.425286251127384
# Expected 3.7
# Predicted 5.818925576598789
# Expected 7.5
# Predicted 7.611524537597105
# Expected 8.1
# Predicted 8.40690893564364
# Expected 8.4
# Predicted 8.780809391841991
# Expected 7.1
# Predicted 8.047700453691427
# Expected 7.6
# Predicted 8.191785243793076
# Expected 7.6
# Predicted 8.225039320428314
# Expected 5.6
# Predicted 6.971529543029582
# Expected 7.0
# Predicted 7.560719823230647
# Expected 10.5
# Predicted 9.906675009150364
# Expected 7.3
# Predicted 8.43605259300882
# Expected 7.8
# Predicted 8.406491935695792
# Expected 5.8
# Predicted 7.140312237900523
# Expected 3.8
# Predicted 5.5811817932156105
# Expected 5.8
# Predicted 6.475811589907615
# Expected 6.7
# Predicted 7.252414140838727
# Expected 6.6
# Predicted 7.370507809288023
# Expected 6.6
# Predicted 7.397687140367423
# Expected 9.0
# Predicted 8.916425139902953
# Expected 8.1
# Predicted 8.705036205648149
# Expected 5.1
# Predicted 6.7668562115917545
# Expected 8.6
# Predicted 8.511716612653887
# Expected 7.0
# Predicted 7.916836872521423
# Expected 5.5
# Predicted 6.832957385094126
# Expected 7.4
# Predicted 7.769548685785649
# Expected 6.2
# Predicted 7.236949853811871
# Expected 4.2
# Predicted 5.853059503036986
# Expected 6.3
# Predicted 6.842296396800269
# Expected 7.0
# Predicted 7.517251070997821
# Expected 4.0
# Predicted 5.793508842642812
# Expected 8.0
# Predicted 7.889143807718053
# Expected 8.8
# Predicted 8.89439072204133
# Expected 8.8
# Predicted 9.134386930704709
# Expected 6.1
# Predicted 7.4996052343414075
# Expected 8.6
# Predicted 8.672687147529912
# Expected 8.9
# Predicted 9.14261343213166
# Expected 7.8
# Predicted 8.56650421032436
# Expected 5.0
# Predicted 6.673901486039532
# Expected 7.0
# Predicted 7.47004670396822
# Expected 13.3
# Predicted 11.614036691224033
# Expected 7.9
# Predicted 9.227395920678749
# Expected 7.5
# Predicted 8.400821941539101
# Expected 8.3
# Predicted 8.698794244426514
# Expected 7.2
# Predicted 8.084552942822988
# Expected 6.5
# Predicted 7.497549848882848
# Expected 8.9
# Predicted 8.852387721848324
# Expected 7.4
# Predicted 8.245990829275625
# Expected 9.9
# Predicted 9.657182113965934
# Expected 9.3
# Predicted 9.627501981978943
# Expected 10.6
# Predicted 10.430862616490536
# Expected 8.6
# Predicted 9.38049305037503
# Expected 7.2
# Predicted 8.250371092824798
# Expected 12.6
# Predicted 11.336280776248845
# Expected 7.8
# Predicted 9.110858798142685
# Expected 6.3
# Predicted 7.627387001359754
# Expected 9.2
# Predicted 9.061294927310861
# Expected 5.8
# Predicted 7.307028698128131
# Expected 9.0
# Predicted 8.853155102768673
# Expected 5.0
# Predicted 6.762647603535746
# Expected 11.9
# Predicted 10.496985160331782
# Expected 13.4
# Predicted 12.376830536328354
# Expected 10.5
# Predicted 11.050724130548435
# Expected 6.2
# Predicted 8.05802982195654
# Expected 5.1
# Predicted 6.621232947502174
# Expected 9.5
# Predicted 8.992759247034538
# Expected 11.7
# Predicted 10.951819636854243
# Expected 9.2
# Predicted 9.885786297535411
# Expected 7.3
# Predicted 8.443679705239957
# Expected 9.7
# Predicted 9.571154014365788
# Expected 9.4
# Predicted 9.6662572877607
# Expected 10.0
# Predicted 10.06152424697132
# Expected 10.9
# Predicted 10.717565890454477
# Expected 11.0
# Predicted 10.943011799803282
# Expected 10.9
# Predicted 10.93722300468861
# Expected 8.0
# Predicted 9.139734004273867
# Expected 11.2
# Predicted 10.671968444182006
# Expected 7.5
# Predicted 8.767762987562184
# Expected 7.2
# Predicted 8.103301125404704
# Expected 13.2
# Predicted 11.642831483581752
# Expected 12.9
# Predicted 12.350056291608478
# Expected 9.4
# Predicted 10.364311817360889
# Expected 10.2
# Predicted 10.359073609021449
# Expected 9.5
# Predicted 9.925475459944384
# Expected 12.4
# Predicted 11.606665448213047
# Expected 10.2
# Predicted 10.672219503412784
# Expected 13.4
# Predicted 12.409794619153947
# Expected 11.6
# Predicted 11.739384958728534
# Expected 8.0
# Predicted 9.350103276682468
# Expected 9.0
# Predicted 9.362770230786738
# Expected 9.3
# Predicted 9.551077395344782
# Expected 13.5
# Predicted 12.1897596108808
# Expected 8.0
# Predicted 9.470032515540904
# Expected 8.1
# Predicted 8.838874134339262
# Expected 10.0
# Predicted 9.847095808198453
# Expected 8.5
# Predicted 9.181485240048172
# Expected 12.5
# Predicted 11.469711327602711
# Expected 15.0
# Predicted 13.597111943533703
# Expected 13.3
# Predicted 13.086686049255626
# Expected 11.0
# Predicted 11.540868440620189
# Expected 11.9
# Predicted 11.704001809497397
# Expected 8.3
# Predicted 9.527726615952027
# Expected 9.7
# Predicted 9.839488533468668
# Expected 11.3
# Predicted 10.903640470923886
# Expected 12.5
# Predicted 11.912712160775435
# Expected 9.4
# Predicted 10.258783715739987
# Expected 11.4
# Predicted 11.07066018849295
# Expected 13.2
# Predicted 12.384530066537646
# Expected 13.8
# Predicted 13.08761448164142
# Expected 16.0
# Predicted 14.621912828794587
# Expected 10.9
# Predicted 11.869672612019238
# Expected 11.9
# Predicted 11.787380796429785
# Expected 12.4
# Predicted 12.074126257037202
# Expected 13.2
# Predicted 12.639069500576166
# Expected 15.5
# Predicted 14.198231751514058
# Expected 21.6
# Predicted 18.36483745160071
# Expected 14.9
# Predicted 15.280411960062624
# Expected 14.4
# Predicted 14.191195949575043
# Expected 12.9
# Predicted 12.990468784649218
# Expected 13.1
# Predicted 12.810686472984806
# Expected 14.0
# Predicted 13.319438146588567
# Expected 17.9
# Predicted 15.849962285688482
# Expected 17.7
# Predicted 16.369974081347735
# Expected 16.3
# Predicted 15.637401811005514
# Expected 18.3
# Predicted 16.687749517156686
# Expected 13.7
# Predicted 14.11807023525781
# Expected 13.3
# Predicted 13.219633380360687
# Expected 10.6
# Predicted 11.325259687948789
# Expected 14.1
# Predicted 13.008187456059341
# Expected 16.0
# Predicted 14.604500188442044
# Expected 16.5
# Predicted 15.316801625338876
# Expected 14.1
# Predicted 14.014936407717096
# Expected 18.7
# Predicted 16.522893304401123
# Expected 16.2
# Predicted 15.619867055834419
# Expected 14.8
# Predicted 14.528113933786097
# Expected 12.6
# Predicted 12.893725254205393
# Expected 10.4
# Predicted 11.120813240186125
# Expected 12.2
# Predicted 11.787917249010816
# Expected 12.6
# Predicted 12.20209994834565
# Expected 12.1
# Predicted 11.998111495823034
# Expected 17.3
# Predicted 15.15288955515461
# Expected 16.4
# Predicted 15.395010077408966
# Expected 12.6
# Predicted 13.109729862414325
# Expected 12.3
# Predicted 12.34901288121278
# Expected 11.8
# Predicted 11.849677709838819
# Expected 12.0
# Predicted 11.848118757594879
# Expected 12.7
# Predicted 12.279890553551938
# Expected 16.4
# Predicted 14.673327253055241
# Expected 16.0
# Predicted 15.02725321360492
# Expected 13.3
# Predicted 13.446218304666637
# Expected 11.7
# Predicted 12.060106646708393
# Expected 10.4
# Predicted 10.909477727394446
# Expected 14.4
# Predicted 13.09753602759736
# Expected 12.7
# Predicted 12.592997704010656
# Expected 14.8
# Predicted 13.764491358799576
# Expected 13.3
# Predicted 13.131116546283328
# Expected 15.6
# Predicted 14.39335144285738
# Expected 14.5
# Predicted 14.030825122898673
# Expected 14.3
# Predicted 13.816649573464012
# Expected 15.3
# Predicted 14.380820004659023
# Expected 16.4
# Predicted 15.202287920218629
# Expected 14.8
# Predicted 14.420808318794029
# Expected 17.4
# Predicted 15.830404928020732
# Expected 18.8
# Predicted 17.051830283250254
# Expected 22.1
# Predicted 19.405108137790428
# Expected 19.0
# Predicted 18.07725497559313
# Expected 15.5
# Predicted 15.571619934792876
# Expected 15.8
# Predicted 15.13417623429981
# Expected 14.7
# Predicted 14.343410923664283
# Expected 10.7
# Predicted 11.663497763566387
# Expected 11.5
# Predicted 11.495767188456142
# Expected 15.0
# Predicted 13.622371581959948
# Expected 14.5
# Predicted 13.842040785897709
# Expected 14.5
# Predicted 13.896656175919412
# Expected 13.3
# Predicted 13.166550035048935
# Expected 14.3
# Predicted 13.605239933569372
# Expected 14.3
# Predicted 13.714466280201538
# Expected 20.5
# Predicted 17.58392340481506
# Expected 15.0
# Predicted 15.145660757040213
# Expected 17.1
# Predicted 15.834566818881477
# Expected 16.9
# Predicted 15.885177309760136
# Expected 16.9
# Predicted 15.898873507470187
# Expected 13.6
# Predicted 13.863960712278843
# Expected 16.4
# Predicted 15.079262966566478
# Expected 16.1
# Predicted 15.202568963635663
# Expected 12.0
# Predicted 12.706546993947244
# Expected 12.2
# Predicted 12.195547791306826
# Expected 14.8
# Predicted 13.667854258183386
# Expected 14.8
# Predicted 14.042660396100166
# Expected 14.4
# Predicted 13.891736220076169
# Expected 12.9
# Predicted 12.929268193936842
# Expected 13.4
# Predicted 12.992893980332948
# Expected 15.9
# Predicted 14.548619297447223
# Expected 16.1
# Predicted 15.068894835332122
# Expected 17.6
# Predicted 16.126714561802995
# Expected 15.6
# Predicted 15.162690834563275
# Expected 15.0
# Predicted 14.547971305137777
# Expected 13.0
# Predicted 13.15750637353802
# Expected 14.1
# Predicted 13.484154742392214
# Expected 17.3
# Predicted 15.539091636062466
# Expected 15.7
# Predicted 15.076675214575493
# Expected 18.6
# Predicted 16.747383720102068
# Expected 12.7
# Predicted 13.541871409838693
# Expected 14.0
# Predicted 13.522292374027765
# Expected 13.7
# Predicted 13.332587176949989
# Expected 16.3
# Predicted 14.881836458644646
# Expected 20.0
# Predicted 17.559873114694714
# Expected 17.0
# Predicted 16.398463957217366
# Expected 15.2
# Predicted 14.992127630562912
# Expected 16.5
# Predicted 15.434448672023855
# Expected 16.5
# Predicted 15.548110286915808
# Expected 17.3
# Predicted 16.07031969062224
# Expected 19.1
# Predicted 17.313505361271286
# Expected 19.3
# Predicted 17.758635286169927
# Expected 17.3
# Predicted 16.64211972795018
# Expected 19.0
# Predicted 17.40403384396644
# Expected 19.8
# Predicted 18.09469071739642
# Expected 19.3
# Predicted 17.96768690765343
# Expected 17.2
# Predicted 16.642656529430177
# Expected 14.2
# Predicted 14.448611445776162
# Expected 10.3
# Predicted 11.467317886588663
# Expected 13.0
# Predicted 12.384266853403142
# Expected 15.3
# Predicted 14.034608340059894
# Expected 15.0
# Predicted 14.271396823861794
# Expected 12.1
# Predicted 12.542683618305025
# Expected 9.2
# Predicted 10.307697755379905
# Expected 11.0
# Predicted 10.854769295596336
# Expected 15.0
# Predicted 13.462847207200724
# Expected 11.6
# Predicted 12.027340632995722
# Expected 11.6
# Predicted 11.662022896669678
# Expected 15.1
# Predicted 13.7257394800628
# Expected 15.0
# Predicted 14.192326136551891
# Expected 13.6
# Predicted 13.447872155012229
# Expected 12.5
# Predicted 12.579403298058663
# Expected 14.3
# Predicted 13.468079206895183
# Expected 16.0
# Predicted 14.743434497068012
# Expected 17.4
# Predicted 15.93420200920705
# Expected 16.9
# Predicted 15.929197614332207
# Expected 18.0
# Predicted 16.60855117397403
# Expected 20.6
# Predicted 18.390840985614084
# Expected 14.2
# Predicted 14.893228877194092
# Expected 10.9
# Predicted 11.944223985516043
# Expected 11.9
# Predicted 11.826919922576673
# Expected 13.3
# Predicted 12.664116769921229
# Expected 15.3
# Predicted 14.113307589361433
# Expected 14.7
# Predicted 14.10691637994424
# Expected 11.0
# Predicted 11.813823405665934
# Expected 12.2
# Predicted 11.980447350832094
# Expected 14.2
# Predicted 13.259835320701344
# Expected 17.0
# Predicted 15.317812847789511
# Expected 15.8
# Predicted 15.091234892756336
# Expected 15.2
# Predicted 14.662591247414705
# Expected 15.1
# Predicted 14.493464344019793
# Expected 14.7
# Predicted 14.203330601580051
# Expected 18.5
# Predicted 16.48521683084756
# Expected 16.4
# Predicted 15.760154123118632
# Expected 18.4
# Predicted 16.81751227834795
# Expected 15.1
# Predicted 15.041623098754094
# Expected 9.9
# Predicted 11.358451727722773
# Expected 10.2
# Predicted 10.624710080909779
# Expected 12.6
# Predicted 11.934759746919166
# Expected 13.2
# Predicted 12.633623982887253
# Expected 11.5
# Predicted 11.7521759248929
# Expected 13.8
# Predicted 12.960010308011858
# Expected 14.5
# Predicted 13.696359238293647
# Expected 14.7
# Predicted 14.004331811601046
# Expected 11.2
# Predicted 11.907851779508015
# Expected 12.7
# Predicted 12.316810263339761
# Expected 13.7
# Predicted 13.039123405748253
# Expected 11.5
# Predicted 11.854978406277665
# Expected 10.4
# Predicted 10.876042102560561
# Expected 8.9
# Predicted 9.699987598623707
# Expected 11.1
# Predicted 10.77322655167232
# Expected 9.5
# Predicted 10.047713678845756
# Expected 13.0
# Predicted 12.037391367647617
# Expected 13.9
# Predicted 13.09441206440812
# Expected 12.6
# Predicted 12.550155143402106
# Expected 14.3
# Predicted 13.469871639729753
# Expected 16.0
# Predicted 14.755340263068659
# Expected 13.3
# Predicted 13.399248569425902
# Expected 7.0
# Predicted 9.138677008940816
# Expected 4.9
# Predicted 6.762502425262986
# Expected 6.9
# Predicted 7.44548596820272
# Expected 13.7
# Predicted 11.868961723651674
# Expected 10.6
# Predicted 10.994700548823854
# Expected 12.3
# Predicted 11.846668407071284
# Expected 11.1
# Predicted 11.303765908721077
# Expected 10.2
# Predicted 10.609758450899315
# Expected 9.5
# Predicted 10.003854058176353
# Expected 8.9
# Predicted 9.481855780016154
# Expected 13.4
# Predicted 12.16621276940974
# Expected 9.1
# Predicted 10.135536862206365
# Expected 9.4
# Predicted 9.826733851354692
# Expected 8.7
# Predicted 9.314807004692545
# Expected 5.8
# Predicted 7.380323946758329
# Expected 4.5
# Predicted 6.09419432666688
# Expected 7.2
# Predicted 7.4693217210160485
# Expected 10.0
# Predicted 9.556094921524773
# Expected 10.5
# Predicted 10.374237080632975
# Expected 10.7
# Predicted 10.696314578895171
# Expected 8.2
# Predicted 9.210480047602545
# Expected 6.1
# Predicted 7.536041820346956
# Expected 4.5
# Predicted 6.128149341622882
# Expected 6.1
# Predicted 6.794334925342083
# Expected 9.8
# Predicted 9.277451668821977
# Expected 9.7
# Predicted 9.807826568716983
# Expected 8.2
# Predicted 8.992688615789612
# Expected 8.4
# Predicted 8.923255997600819
# Expected 8.5
# Predicted 8.969206483106403
# Expected 10.4
# Predicted 10.172114256405512
# Expected 6.8
# Predicted 8.203197139744335
# Expected 6.0
# Predicted 7.227948506831452
# Expected 6.6
# Predicted 7.370494336876747
# Expected 7.8
# Predicted 8.157342351892336
# Expected 10.3
# Predicted 9.915775674835219
# Expected 7.2
# Predicted 8.390535646896637
# Expected 7.4
# Predicted 8.150087882592683
# Expected 11.4
# Predicted 10.599135938339794
# Expected 5.4
# Predicted 7.436822580896758
# Expected 4.4
# Predicted 6.040573602251146
# Expected 6.4
# Predicted 6.954763085003846
# Expected 9.3
# Predicted 8.992457951821892
# Expected 7.7
# Predicted 8.481679432408127
# Expected 8.1
# Predicted 8.608518804854613
# Expected 8.3
# Predicted 8.764084917499
# Expected 9.1
# Predicted 9.301876902579032
# Expected 7.7
# Predicted 8.556775854496788
# Expected 10.6
# Predicted 10.18808347109504
# Expected 8.2
# Predicted 9.085026714575326
# Expected 7.9
# Predicted 8.629128972147182
# Expected 5.2
# Predicted 6.831105582737661
# Expected 5.9
# Predicted 6.830198636068395
# Expected 3.7
# Predicted 5.4533298575961275
# Expected 5.6
# Predicted 6.305875127807838
# Expected 9.4
# Predicted 8.893308347749905
# Expected 7.4
# Predicted 8.266907693949594
# Expected 7.3
# Predicted 8.052812132219634
# Expected 7.7
# Predicted 8.250276851970899
# Expected 7.7
# Predicted 8.298077140956265
# Expected 9.3
# Predicted 9.309270307157654
# Expected 4.4
# Predicted 6.498290708477825
# Expected 5.7
# Predicted 6.619097461195532
# Expected 10.2
# Predicted 9.457675519531474
# Expected 10.2
# Predicted 10.153280436694741
# Expected 9.3
# Predicted 9.760666078017882
# Expected 5.4
# Predicted 7.231662058890409
# Expected 5.0
# Predicted 6.360755021094964
# Expected 7.6
# Predicted 7.773793063403701
# Expected 9.6
# Predicted 9.369621797243257
# Expected 10.4
# Predicted 10.257967477469128
# Expected 11.2
# Predicted 10.973617126780978
# Expected 9.1
# Predicted 9.833263972777152
# Expected 11.2
# Predicted 10.869540874657247
# Expected 6.8
# Predicted 8.373227383569066
# Expected 8.3
# Predicted 8.70136810197037
# Expected 9.7
# Predicted 9.65559982507424
# Expected 9.6
# Predicted 9.825565484695527
# Expected 9.8
# Predicted 9.991803677181482
# Expected 10.8
# Predicted 10.656765314977216
# Expected 9.2
# Predicted 9.81978296118703
# Expected 6.5
# Predicted 7.92904815629514
# Expected 8.1
# Predicted 8.467824652806888
# Expected 7.3
# Predicted 8.098992387495745
# Expected 7.9
# Predicted 8.38363793746129
# Expected 6.0
# Predicted 7.265963055460154
# Expected 5.0
# Predicted 6.367457969035384
# Expected 6.8
# Predicted 7.272728671635189
# Expected 9.8
# Predicted 9.370540896860025
# Expected 5.7
# Predicted 7.31961930175744
# Expected 8.6
# Predicted 8.62506722059687
# Expected 10.6
# Predicted 10.19405072200821
# Expected 7.8
# Predicted 8.833570728886869
# Expected 7.7
# Predicted 8.436332855661934
# Expected 8.6
# Predicted 8.898859780590312
# Expected 6.5
# Predicted 7.704846139246487
# Expected 6.9
# Predicted 7.658824735503933
# Expected 6.4
# Predicted 7.335586145764191
# Expected 8.5
# Predicted 8.563730695213861
# Expected 7.8
# Predicted 8.430359416589475
# Expected 9.3
# Predicted 9.331461215043607
# Expected 8.4
# Predicted 8.993437343210656
# Expected 7.8
# Predicted 8.536345057061625
# Expected 7.4
# Predicted 8.174030558172825
# Expected 7.7
# Predicted 8.270894829485893
# Expected 8.9
# Predicted 9.04179603115515
# Expected 9.7
# Predicted 9.730569057495236
# Expected 9.9
# Predicted 10.025164672499312
# Expected 6.1
# Predicted 7.733529288808764
# Expected 6.6
# Predicted 7.476149601326717
# Expected 7.6
# Predicted 8.035198376354344
# Expected 7.4
# Predicted 8.048519606850284
# Expected 8.0
# Predicted 8.425179807473945
# Expected 2.1
# Predicted 4.848152608866878
# Expected 5.9
# Predicted 6.319505839002411
# Expected 11.6
# Predicted 10.238277110176673
# Expected 8.6
# Predicted 9.339512259793134
# Expected 7.9
# Predicted 8.683230383900954
# Expected 6.0
# Predicted 7.339158556207315
# Expected 9.5
# Predicted 9.175834241465829
# Expected 8.6
# Predicted 9.076170686000827
# Expected 7.6
# Predicted 8.430952296645607
# Expected 10.4
# Predicted 10.005322861185126
# Expected 10.3
# Predicted 10.338132385147697
# Expected 7.5
# Predicted 8.686247778988394
# Expected 3.0
# Predicted 5.474819893775205
# Expected 5.3
# Predicted 6.102324101669574
# Expected 10.5
# Predicted 9.493142337753149
# Expected 14.6
# Predicted 12.909409171292769
# Expected 12.6
# Predicted 12.485248683774754
# Expected 9.8
# Predicted 10.634475799411474
# Expected 7.2
# Predicted 8.555445546551162
# Expected 10.1
# Predicted 9.864568298061233
# Expected 10.4
# Predicted 10.370005374934163
# Expected 3.7
# Predicted 6.312703275311554
# Expected 7.3
# Predicted 7.5648621648888925
# Expected 11.6
# Predicted 10.555130941755692
# Expected 16.3
# Predicted 14.242702199831097
# Expected 9.6
# Predicted 10.934316269709202
# Expected 6.8
# Predicted 8.377711869499196
# Expected 5.2
# Predicted 6.754605896436667
# Expected 10.6
# Predicted 9.747216689582654
# Expected 16.3
# Predicted 14.060567637177497
# Expected 9.8
# Predicted 11.002849512000761
# Expected 4.6
# Predicted 7.0057722021235
# Expected 11.1
# Predicted 10.119248540129977
# Expected 8.7
# Predicted 9.371759357401467
# Expected 10.0
# Predicted 10.00045239023384
# Expected 11.3
# Predicted 10.964108667206256
# Expected 10.5
# Predicted 10.699765814663568
# Expected 9.9
# Predicted 10.261490994583738
# Expected 11.0
# Predicted 10.840286075769352
# Expected 14.0
# Predicted 12.851929600243322
# Expected 9.2
# Predicted 10.352941024514747
# Expected 9.8
# Predicted 10.114863614066023
# Expected 6.0
# Predicted 7.689943347756658
# Expected 9.8
# Predicted 9.462750020031487
# Expected 9.2
# Predicted 9.523353710495783
# Expected 11.8
# Predicted 11.155685184929359
# Expected 10.3
# Predicted 10.622545077896095
# Expected 7.5
# Predicted 8.75107219623369
# Expected 7.7
# Predicted 8.415654370591948
# Expected 15.8
# Predicted 13.366932088553815
# Expected 14.6
# Predicted 13.840203570412946
# Expected 10.5
# Predicted 11.40500555973119
# Expected 11.3
# Predicted 11.30547650967804
# Expected 10.9
# Predicted 11.032502026738417
# Expected 6.4
# Predicted 8.16695929830984
# Expected 10.9
# Predicted 10.260879052383373
# Expected 9.0
# Predicted 9.596553767752924
# Expected 10.9
# Predicted 10.61067115306661
# Expected 12.4
# Predicted 11.792130971785502
# Expected 11.6
# Predicted 11.587031610197787
# Expected 13.3
# Predicted 12.591041909706394
# Expected 14.4
# Predicted 13.521677744926937
# Expected 18.4
# Predicted 16.23815640432442
# Expected 13.6
# Predicted 13.923457172541058
# Expected 14.9
# Predicted 14.161130728490473
# Expected 14.8
# Predicted 14.15786990170396
# Expected 15.4
# Predicted 14.529449127702366
# Expected 11.8
# Predicted 12.389483125675728
# Expected 13.0
# Predicted 12.604160064274787
# Expected 11.1
# Predicted 11.479715533630008
# Expected 12.5
# Predicted 12.068706104596298
# Expected 18.3
# Predicted 15.808588990933837
# Expected 19.2
# Predicted 17.30118637729144
# Expected 15.4
# Predicted 15.300899687062191
# Expected 13.1
# Predicted 13.376618188732834
# Expected 11.5
# Predicted 11.908673995443548
# Expected 8.6
# Predicted 9.740910917196825
# Expected 12.6
# Predicted 11.714120633052879
# Expected 13.8
# Predicted 12.940093916047783
# Expected 14.6
# Predicted 13.735945716997852
# Expected 13.2
# Predicted 13.054589987469978
# Expected 12.3
# Predicted 12.32861372055547
# Expected 8.8
# Predicted 9.967209096674335
# Expected 10.7
# Predicted 10.58651061526183
# Expected 9.9
# Predicted 10.235952280306433
# Expected 8.3
# Predicted 9.152793475033638
# Expected 15.0
# Predicted 13.067302154705953
# Expected 12.2
# Predicted 12.269990045270395
# Expected 10.5
# Predicted 11.019057968215533
# Expected 11.1
# Predicted 11.088793594522762
# Expected 13.0
# Predicted 12.288158549770387
# Expected 12.9
# Predicted 12.51746073285793
# Expected 8.8
# Predicted 10.022036803354952
# Expected 14.7
# Predicted 13.077652566251746
# Expected 14.7
# Predicted 13.828829000098864
# Expected 12.7
# Predicted 12.770887911046525
# Expected 13.3
# Predicted 12.884019938042062
# Expected 13.2
# Predicted 12.849799508028724
# Expected 16.2
# Predicted 14.702867759274742
# Expected 17.3
# Predicted 15.843006448920878
# Expected 20.5
# Predicted 18.11564018661859
# Expected 20.2
# Predicted 18.485199937088872
# Expected 19.4
# Predicted 18.077212755732504
# Expected 15.5
# Predicted 15.541366520603209
# Expected 14.1
# Predicted 14.050900984320187
# Expected 11.0
# Predicted 11.749922555334726
# Expected 11.1
# Predicted 11.264892442101688
# Expected 14.0
# Predicted 12.964080854772956
# Expected 11.4
# Predicted 11.744236376858815
# Expected 12.5
# Predicted 12.140032856846542
# Expected 13.4
# Predicted 12.79729631220562
# Expected 13.6
# Predicted 13.079880242760403
# Expected 13.9
# Predicted 13.335203902086342
# Expected 17.2
# Predicted 15.460051536731068
# Expected 14.7
# Predicted 14.406101075249518
# Expected 15.4
# Predicted 14.591742834050468
# Expected 13.1
# Predicted 13.198525519473572
# Expected 13.2
# Predicted 12.927107659681818
# Expected 13.9
# Predicted 13.299618900977975
# Expected 10.0
# Predicted 10.952390010882855
# Expected 12.9
# Predicted 12.199953899285301
# Expected 14.6
# Predicted 13.561180828017529
# Expected 14.0
# Predicted 13.51462220133639
# Expected 13.6
# Predicted 13.25378323297792
# Expected 13.5
# Predicted 13.128720622304407
# Expected 15.7
# Predicted 14.472034527335854
# Expected 13.0

# %%
plt.figure(figsize=(16, 5))
plt.plot(test)
plt.plot(predictions, color='red')
plt.show()

# %%
from sklearn.metrics import mean_squared_error
from numpy import sqrt

# %%
sqrt(mean_squared_error(test, predictions))
# Out:
# 2.4275712374932046
