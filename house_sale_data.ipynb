# %%
from pandas import DataFrame
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sb
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error, mean_squared_error
import numpy as np

# %%
path = '/home/mehul/Documents/training/python/data/kc_house_data.csv'

# %%
df = pd.read_csv(path)
df
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000   221900.0         3       1.00
# 1      6414100192  20141209T000000   538000.0         3       2.25
# 2      5631500400  20150225T000000   180000.0         2       1.00
# 3      2487200875  20141209T000000   604000.0         4       3.00
# 4      1954400510  20150218T000000   510000.0         3       2.00
# 5      7237550310  20140512T000000  1225000.0         4       4.50
# 6      1321400060  20140627T000000   257500.0         3       2.25
# 7      2008000270  20150115T000000   291850.0         3       1.50
# 8      2414600126  20150415T000000   229500.0         3       1.00
# 9      3793500160  20150312T000000   323000.0         3       2.50
# 10     1736800520  20150403T000000   662500.0         3       2.50
# 11     9212900260  20140527T000000   468000.0         2       1.00
# 12      114101516  20140528T000000   310000.0         3       1.00
# ...

# %%
df.shape
# Out:
# (21613, 21)

# %%
df.describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.161300e+04  2.161300e+04  21613.000000  21613.000000  21613.000000
# mean   4.580302e+09  5.400881e+05      3.370842      2.114757   2079.899736
# std    2.876566e+09  3.671272e+05      0.930062      0.770163    918.440897
# min    1.000102e+06  7.500000e+04      0.000000      0.000000    290.000000
# 25%    2.123049e+09  3.219500e+05      3.000000      1.750000   1427.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  2.161300e+04  21613.000000  21613.000000  21613.000000  21613.000000
# mean   1.510697e+04      1.494309      0.007542      0.234303      3.409430
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
# id               21613 non-null int64
# date             21613 non-null object
# price            21613 non-null float64
# bedrooms         21613 non-null int64
# bathrooms        21613 non-null float64
# sqft_living      21613 non-null int64
# sqft_lot         21613 non-null int64
# floors           21613 non-null float64
# waterfront       21613 non-null int64
# view             21613 non-null int64
# condition        21613 non-null int64
# grade            21613 non-null int64
# sqft_above       21613 non-null int64
# sqft_basement    21613 non-null int64
# yr_built         21613 non-null int64
# yr_renovated     21613 non-null int64
# zipcode          21613 non-null int64
# lat              21613 non-null float64
# long             21613 non-null float64
# sqft_living15    21613 non-null int64
# sqft_lot15       21613 non-null int64
# ...

# %%
corr = df.corr()
corr
# Out:
#                      id     price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# id             1.000000 -0.016762  0.001286   0.005160    -0.012258 -0.132109
# price         -0.016762  1.000000  0.308350   0.525138     0.702035  0.089661
# bedrooms       0.001286  0.308350  1.000000   0.515884     0.576671  0.031703
# bathrooms      0.005160  0.525138  0.515884   1.000000     0.754665  0.087740
# sqft_living   -0.012258  0.702035  0.576671   0.754665     1.000000  0.172826
# sqft_lot      -0.132109  0.089661  0.031703   0.087740     0.172826  1.000000
# floors         0.018525  0.256794  0.175429   0.500653     0.353949 -0.005201
# waterfront    -0.002721  0.266369 -0.006582   0.063744     0.103818  0.021604
# view           0.011592  0.397293  0.079532   0.187737     0.284611  0.074710
# condition     -0.023783  0.036362  0.028472  -0.124982    -0.058753 -0.008958
# grade          0.008130  0.667434  0.356967   0.664983     0.762704  0.113621
# ...

# %%
sb.heatmap(corr)
plt.show()

# %%
features_extracted = ['sqft_living15', 'sqft_above', 'grade', 'sqft_living']

# %%
df.plot.scatter(x='sqft_living', y='price')
plt.show()

# %%
df.plot.scatter(x='sqft_above', y='price')
plt.show()

# %%
df.plot.scatter(x='grade', y='price')
plt.show()

# %%
df.plot.scatter(x='sqft_living15', y='price')
plt.show()

# %%
df.plot.scatter(x='sqft_living15', y='sqft_living')
plt.show()

# %%
df.plot.scatter(x='sqft_lot', y='price')
plt.show()

# %%
x = df[['sqft_living']].values
x
# Out:
# array([[1180],
#        [2570],
#        [ 770],
#        ...,
#        [1020],
#        [1600],
#        [1020]])

# %%
y = df['price'].values
y
# Out:
# array([ 221900.,  538000.,  180000., ...,  402101.,  400000.,  325000.])

# %%
# separate out the data to training data and test data
# strictly give training data (seen) to the model for learning
# stictly give the test data (unseen) to the model for prediction
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2)

# %%
lr1 = LinearRegression()
lr1.fit(x_train, y_train) # training
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
print(x_train)
# Out:
# [[2310]
#  [1520]
#  [1930]
#  ...,
#  [1660]
#  [2270]
#  [2270]]

# %%
y_pred = lr1.predict(x_test) # testing

# %%
print(x_test)
# Out:
# [[1780]
#  [1000]
#  [1270]
#  ...,
#  [2510]
#  [1760]
#  [2040]]

# %%
print(y_test)
# Out:
# [ 336000.  505000.  340000. ...,  571000.  224000.  500000.]

# %%
print(y_pred)
# Out:
# [ 455439.12102387  236757.16640435  312454.76608034 ...,  660103.00162933
#   449831.89141825  528333.10589705]

# %%
plt.scatter(x_train, y_train)
plt.plot(x_test, y_pred, color='red')
plt.show()

# %%
print(mean_absolute_error(y_test, y_pred))
print(np.sqrt(mean_squared_error(y_test, y_pred)))
# Out:
# 174428.060725
# 258306.793227

# %%
lr1.score(x_train, y_train)
# Out:
# 0.49120977036593894

# %%
x2 = df[['sqft_living', 'grade', 'sqft_above']].values
x2
# Out:
# array([[1180,    7, 1180],
#        [2570,    7, 2170],
#        [ 770,    6,  770],
#        ...,
#        [1020,    7, 1020],
#        [1600,    8, 1600],
#        [1020,    7, 1020]])

# %%
y2 = df['price'].values
y2
# Out:
# array([ 221900.,  538000.,  180000., ...,  402101.,  400000.,  325000.])

# %%
x2_train, x2_test, y2_train, y2_test = train_test_split(x2, y2, test_size=0.2)

# %%
lr2 = LinearRegression()
lr2.fit(x2_train, y2_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
y2_pred = lr2.predict(x2_test)

# %%
print(x2_test)
# Out:
# [[3280    9 2190]
#  [2990    9 1560]
#  [1050    6  840]
#  ...,
#  [1980    8 1980]
#  [ 910    6  910]
#  [1870    8 1870]]

# %%
print(y2_test)
# Out:
# [ 706000.  820000.  209950. ...,  319950.  280000.  770000.]

# %%
print(y2_pred)
# Out:
# [ 936424.68234837  919927.81568198  190795.78198729 ...,  540416.67860125
#   152938.48166436  523855.0136052 ]

# %%
print(mean_absolute_error(y2_test, y2_pred))
print(np.sqrt(mean_squared_error(y2_test, y2_pred)))
# Out:
# 161888.277754
# 247197.354973

# %%
lr2.score(x2_train, y2_train)
# Out:
# 0.53613548671269551
