# %%
import pandas as pd
import matplotlib.pyplot as plt
# Out:
# /home/mehul/anaconda3/lib/python3.7/importlib/_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)

# %%
d1 = pd.read_csv('/home/mehul/Documents/training/python/data/trend-data.csv', parse_dates=['date'], index_col=0)
d2 = pd.read_csv('/home/mehul/Documents/training/python/data/seasonal-data.csv', parse_dates=['date'], index_col=0)
d3 = pd.read_csv('/home/mehul/Documents/training/python/data/trend-seasonal-data.csv', parse_dates=['date'], index_col=0)

# %%
d1.head(5)
# Out:
#                value
# date
# 1970-01-01  0.311405
# 1971-01-01  0.325180
# 1972-01-01  0.339565
# 1973-01-01  0.354580
# 1974-01-01  0.370265

# %%
d2.head(5)
# Out:
#                  value
# date
# 1875-01-01  213.133333
# 1876-01-01  109.283333
# 1877-01-01   92.858333
# 1878-01-01   22.216667
# 1879-01-01   36.333333

# %%
d3.head(5)
# Out:
#             value
# date
# 1949-01-01    112
# 1949-02-01    118
# 1949-03-01    132
# 1949-04-01    129
# 1949-05-01    121

# %%
fig, axes = plt.subplots(1, 3, figsize=(18, 4))
d1.plot(ax=axes[0], title='Trend only', legend=False)
d2.plot(ax=axes[1], title='Seasonal only', legend=False)
d3.plot(ax=axes[2], title='Trend + Seasonal', legend=False)
plt.show()
